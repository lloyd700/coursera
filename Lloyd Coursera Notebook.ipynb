# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Lloyd Tatenda Chimanga**
# Software Developer

# %% [markdown]
# *I am interested in Data Science because it is the new trend and there are opportunities for jobs*

# %% [markdown]
# ### My code is supposed to multiply the number 2 by 3 to get 6 as result.

# %%
2*3
# Out:
# 6

# %% [markdown]
# - bullet list one
#     -sub buller list one
#     -sub buller list two
# - bullet list two
#     -sub buller list one
#     -sub buller list two
#     -sub buller list three
#     -sub buller list four
#
# 1. Numbered list one
# 2. Numbered list two
# 3. Numbered list three
# 4. Numbered list four
#
# www.ibm.com
#
# <img src ="https://i.picsum.photos/id/0/400/400.jpg?hmac=SU3aYlAKtJ-3OJNC46tIX5A7lSjJIUOphnwRH53POqE">
